# %% [markdown]
# <a href="https://www.kaggle.com/code/anannaabiswas02/mlb-2-class-6-assignment?scriptVersionId=348270122" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import datasets on a dataframe

# %%
store = pd.read_csv('/kaggle/input/datasets/binib1997/superstore/Superstore.csv', encoding='latin-1')
titanic = pd.read_csv('/kaggle/input/datasets/lovishbansal123/titanic-dataset/Titanic-Dataset.csv')
iris = pd.read_csv('/kaggle/input/datasets/himanshunakrani/iris-dataset/iris.csv')
tips = pd.read_csv('/kaggle/input/datasets/saurabhbadole/restaurant-tips-dataset/tips.csv')
climate = pd.read_csv('/kaggle/input/datasets/sumanthvrao/daily-climate-time-series-data/DailyDelhiClimateTrain.csv')

# %% [markdown]
# # Series

# %% [markdown]
# # 1. Create a series from a list

# %%
nums = [65, 54, 32, 80, 84, 70]
label = ['bangla', 'english', 'math', 'physics', 'chemistry', 'biology']
nums = pd.Series(nums, index=label)
print(nums)

# %% [markdown]
# # 2. Create series from a dictionary

# %%
info = {
    'name': 'Ananna',
    'id': 32,
    'age': 24,
    'address': 'Khulna'
}
info = pd.Series(info)
print(info)

# %% [markdown]
# # 3. Create a series from dataframe

# %%
tips

# %%
bill = tips['total_bill']
print(bill)

# %% [markdown]
# # 4. Apply below operations on a series to understand about a series

# %%
# head
# tail
# sample
# size
# dtype
# astype
# index
# values

# %%
bill.head()

# %%
bill.tail()

# %%
bill.sample()

# %%
bill.size

# %%
bill.dtype

# %%
nums = nums.astype('int32')
nums.dtype

# %%
nums.index

# %%
nums.values

# %% [markdown]
# # 5. Change data-type of a series

# %%
titanic

# %%
age = titanic['Age']
age = age.astype('str')
age.dtype

# %% [markdown]
# # 6. Apply below mathematical operations on a series

# %%
# count
# sum
# product
# min
# max
# mean
# median
# mode
# describe
# std
# var

# %%
bill

# %%
print(bill.count())

# %%
bill.sum()

# %%
bill.product()

# %%
bill.min()

# %%
bill.max()

# %%
bill.mean()

# %%
bill.median()

# %%
bill.mode()

# %%
bill.describe()

# %%
bill.std()

# %%
bill.var()

# %% [markdown]
# # 7. Do 3 slicing operations on a series

# %%
bill[4:8]

# %%
bill[92:106]

# %%
bill.iloc[237:]

# %% [markdown]
# # Dataframe

# %% [markdown]
# # 1. Create a dataframe from a list

# %%
num = [
    [92, 87, 54, 72],
    [82, 68, 90, 76],
    [83, 76, 88, 84]
]
sub = ['Bang', 'Eng', 'Math', 'Phy']
mark = pd.DataFrame(num,columns=sub)
print(mark)

# %% [markdown]
# # 2. Apply below dataframe understanding operations

# %%
# head
# tail
# sample
# info
# isnull
# duplicated

# %%
store

# %%
store.head()

# %%
store.tail()

# %%
store.sample()

# %%
store.info()

# %%
titanic.isnull().sum()

# %%
tips.duplicated().sum()

# %% [markdown]
# # 2. Apply below dataframe attribute operations

# %%
# shape
# dtypes
# columns
# values

# %%
store.shape

# %%
store.dtypes

# %%
store.columns

# %%
store['City'].values

# %% [markdown]
# # 3. Apply below mathematical operations on a feature taken from dataframe

# %%
# count
# sum
# product
# min
# max
# mean
# median
# mode
# describe
# std
# var

# %%
store['Profit'].count()

# %%
store['Profit'].sum()

# %%
tips['tip'].product()

# %%
store['Profit'].min()

# %%
store['Profit'].max()

# %%
store['Profit'].mean()

# %%
store['Profit'].median()

# %%
store['Profit'].mode()

# %%
store['Profit'].describe()

# %%
store['Profit'].std()

# %%
store['Profit'].var()

# %% [markdown]
# # Selection and filtering

# %%
# loc
# iloc
# isin()
# logical operation (&, |, ~)

# %% [markdown]
# # 1. Select 11-20th rows and total_bill and tip columns from tips dataframe

# %%
tips

# %%
tips.iloc[11:21,0:2]

# %% [markdown]
# # 2. Select 0-20th rows and total_bill, tip and day columns from tips dataframe

# %%
tips.loc[0:20,['total_bill','tip','day']]

# %% [markdown]
# # 3. Select customers who comes in sunday and total_bill is greater than 20 dollars

# %%
tips[(tips['day'].isin(['Sun'])) & (tips['total_bill'] > 20)]

# %% [markdown]
# # 4. Select passengers who are male and age greater than 50 from titanic

# %%
titanic[(titanic['Sex'].isin(['male'])) & (titanic['Age'] > 50)]

# %% [markdown]
# # 5. Select customers who are female and tip greater than 5 dollars from tips dataframe - write query operation

# %%
tips[(tips['sex'].isin(['Female'])) & (tips['tip'] > 5)]

# %% [markdown]
# # groupby

# %%
store

# %% [markdown]
# # 1. group on region based in store dataframe

# %%
reg = store.groupby('Region')
print(reg)

# %% [markdown]
# # 2. Find region-wise average sales

# %%
reg['Sales'].mean()

# %% [markdown]
# # 3. Find region-wise average profit

# %%
reg['Profit'].mean()

# %% [markdown]
# # 4. Find region-wise maximum profit

# %%
reg['Profit'].max()

# %% [markdown]
# # 5. Apply multiple aggregate functions on region-wise sales

# %%
reg['Sales'].agg(['max','min','mean','std','var'])

# %% [markdown]
# # 6. group on region and category wise

# %%
mtp = store.groupby(['Region','Category'])

# %% [markdown]
# # 7. Find region and category wise average sales

# %%
mtp['Sales'].mean()

# %% [markdown]
# # 8. Find region and category wise average, minimumm, maximum and sum sales

# %%
mtp['Sales'].agg(['mean','min','max','sum'])

# %% [markdown]
# # Merging and joining

# %%
students = pd.DataFrame({
    "student_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                   111, 112, 113, 114, 115, 116, 117, 118, 119, 120],
    "name": ["Rahim", "Karim", "Hasan", "Sakib", "Nabil",
             "Tanvir", "Fahim", "Rafi", "Imran", "Shakil",
             "Arif", "Jahid", "Mehedi", "Siam", "Tareq",
             "Rakib", "Adnan", "Nayeem", "Foysal", "Rony"],
    "department": ["CSE", "EEE", "CSE", "BBA", "CSE",
                   "EEE", "CSE", "BBA", "CSE", "EEE",
                   "CSE", "BBA", "EEE", "CSE", "BBA",
                   "CSE", "EEE", "CSE", "BBA", "EEE"]
})

students

# %%
results = pd.DataFrame({
    "student_id": [101, 102, 103, 105, 106, 108, 109, 111, 112, 114,
                   121, 122, 123, 124, 125, 126, 127, 128, 129, 130],
    "math": [85, 72, 91, 68, 77, 88, 74, 95, 81, 69,
             78, 84, 92, 73, 89, 67, 80, 94, 76, 83],
    "python": [90, 75, 88, 72, 80, 92, 79, 96, 85, 71,
               82, 87, 95, 76, 91, 70, 84, 93, 78, 86]
})

results

# %%
departments = pd.DataFrame({
    "dept_id": [1, 2, 3, 4],
    "department": [
        "CSE",
        "EEE",
        "BBA",
        "Civil"
    ],
    "faculty": [
        "Engineering",
        "Engineering",
        "Business",
        "Engineering"
    ]
})

departments

# %% [markdown]
# # 1. Create a dataframe contains students name,faculty and number on math and python

# %%
data1 = students.merge(results, on ='student_id')
data = data1.merge(departments, on='department')
data_sub = data[['name', 'faculty', 'math', 'python']]
data_sub

# %% [markdown]
# # 2. Department wise students count

# %%
data.groupby('department').count()

# %% [markdown]
# # 3. Faculty wise department count

# %%
data.groupby('faculty').count()

# %% [markdown]
# # 4. Find department wise highest number on each subject

# %%
data[['department','math','python']].groupby('department').max()

# %% [markdown]
# # 5. Find faculty wise highest number on each subject

# %%
data[['faculty','math','python']].groupby('faculty').max()

# %% [markdown]
# # Time-series

# %%
# use climate dataset
climate

# %% [markdown]
# # 1. convert time into datetime

# %%
climate['date'] =  pd.to_datetime(climate['date'])
climate['date']

# %% [markdown]
# # 2. set date as index

# %%
climate = climate.set_index('date')

# %%
climate

# %% [markdown]
# # 3. Select row of 13 january, 2015

# %%
climate.loc['2015-01-13']

# %% [markdown]
# # 4. Select rows contains in april 2017

# %%
climate.loc['2017-04-01':'2017-04-30']

# %% [markdown]
# # 5. Select rows from 11 september, 2014 to 25 september, 2014

# %%
climate.loc['2014-09-11':'2014-09-25']

# %% [markdown]
# # 6. Calculate month-wise average windspeed

# %%
climate['wind_speed'].resample('ME').mean()

# %% [markdown]
# # 7. Calculate month-wise highest meantemp

# %%
climate['meantemp'].resample('ME').max()

# %% [markdown]
# # 8. Year-wise maximum, minimum and average humidity

# %%
climate['humidity'].resample('YE').agg(['max','min','mean'])

# %% [markdown]
# # 9. A new column contains previous 10 days average meantemp

# %%
climate['prev_10d'] = climate['meantemp'].rolling(10).mean()

# %%
climate
# Out:
#              meantemp    humidity  wind_speed  meanpressure   prev_10d
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667        NaN
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000        NaN
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667        NaN
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667        NaN
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000        NaN
# ...               ...         ...         ...           ...        ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217  17.107129
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762  16.845224
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762  16.274748
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000  15.975011
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000  15.246440
#
# [1462 rows x 5 columns]
